# %%
import tensorflow as tf
import pandas as pd
from bokeh.plotting import figure, output_file, show
from bokeh.models import HoverTool
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import numpy as np
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Input,Dense, Subtract, Add, Concatenate, Dropout
from tensorflow.keras.optimizers import Adam
from keras import regularizers
from keras.constraints import maxnorm
from sklearn.linear_model import Lasso
from keras.callbacks import EarlyStopping


data = pd.read_excel("C:/Users/ERIC/Desktop/PML-06MTP-115/06MTP-115.xlsm", 0)

# Training dataset
x = data.iloc[:, 1:5].values
y = data.iloc[:, 5:6].values

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2, random_state = 42) #try random_state = 42

#Standarization of the data
sc = StandardScaler()
std_x_train = sc.fit_transform(x_train)
std_x_test = sc.fit_transform(x_test)

input_tensor = Input(shape=(x.shape[1],))
#layer_drop = Dropout(0.3)

hidden_layer = Dense(50, activation = 'relu', kernel_constraint=maxnorm(3),#Make better results with Dropout
                     kernel_regularizer=regularizers.l2(0.01), bias_regularizer=regularizers.l2(0.01),#To avoid Over-fitting
                     activity_regularizer=regularizers.l1(0.0001))(input_tensor) #Regularize the wieghts to have better accuracy


hidden_layer1 = Dense(25, activation = 'relu',kernel_constraint=maxnorm(3),#Make better results with Dropout
                     kernel_regularizer=regularizers.l2(0.01), bias_regularizer=regularizers.l2(0.01),#To avoid Over-fitting
                     activity_regularizer=regularizers.l1(0.0001))(hidden_layer) #Regularize the wieghts to have better accuracy


hidden_layer2 = Dense(10, activation = 'relu', kernel_constraint=maxnorm(3),#Make better results with Dropout
                     kernel_regularizer=regularizers.l2(0.01), bias_regularizer=regularizers.l2(0.01),#To avoid Over-fitting
                     activity_regularizer=regularizers.l1(0.0001))(hidden_layer1) #Regularize the wieghts to have better accuracy
layer_drop2 = Dropout(0.3)

output_tensor = Dense(1)(hidden_layer2)

model = Model(input_tensor, output_tensor)

model.compile(optimizer= 'adam',  loss='mean_absolute_error', metrics = ['mean_absolute_error'])

#monitor = EarlyStopping(monitor = 'val_loss', min_delta = 1e-3, patience = 5, verbose = 1, mode = 'auto', 
                        #restore_best_weights = True)

model.summary()

model.fit(x_train,
          y_train,
          #validation_data = (x_test, y_test),
          #callbacks = [monitor],
          epochs=100,
          batch_size = 3,
          validation_split = 0.1,
          verbose=True)

pred = model.predict(x_test)
score = np.sqrt(mean_squared_error(pred,y_test))
print("Final score (RMSE): {}".format(score))
# Out:
# Model: "model_17"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_18 (InputLayer)        [(None, 4)]               0
# _________________________________________________________________
# dense_78 (Dense)             (None, 50)                250
# _________________________________________________________________
# dense_79 (Dense)             (None, 25)                1275
# _________________________________________________________________
# dense_80 (Dense)             (None, 10)                260
# _________________________________________________________________
# dense_81 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 1,796
# Trainable params: 1,796
# Non-trainable params: 0
# _________________________________________________________________
# Train on 327 samples, validate on 37 samples
# Epoch 1/100
# 327/327 [==============================] - 2s 6ms/sample - loss: 81.4950 - mean_absolute_error: 71.6952 - val_loss: 50.0459 - val_mean_absolute_error: 40.4426
# Epoch 2/100
# 327/327 [==============================] - 0s 1ms/sample - loss: 73.3793 - mean_absolute_error: 63.9626 - val_loss: 59.0768 - val_mean_absolute_error: 49.7888
# Epoch 3/100
# 327/327 [==============================] - 0s 981us/sample - loss: 81.9523 - mean_absolute_error: 72.8624 - val_loss: 57.9234 - val_mean_absolute_error: 49.0606
# Epoch 4/100
# 327/327 [==============================] - 0s 868us/sample - loss: 81.6481 - mean_absolute_error: 72.9950 - val_loss: 65.0110 - val_mean_absolute_error: 56.6054
# Epoch 5/100
# 327/327 [==============================] - 0s 915us/sample - loss: 74.3888 - mean_absolute_error: 66.1230 - val_loss: 58.1361 - val_mean_absolute_error: 50.0263
# Epoch 6/100
# 327/327 [==============================] - 0s 840us/sample - loss: 77.9931 - mean_absolute_error: 70.0751 - val_loss: 48.0073 - val_mean_absolute_error: 40.2436
# Epoch 7/100
# 327/327 [==============================] - 0s 868us/sample - loss: 71.6531 - mean_absolute_error: 64.0634 - val_loss: 46.3162 - val_mean_absolute_error: 38.8300
# Epoch 8/100
# 327/327 [==============================] - 0s 865us/sample - loss: 67.5890 - mean_absolute_error: 60.2508 - val_loss: 48.9641 - val_mean_absolute_error: 41.6991
# Epoch 9/100
# 327/327 [==============================] - 0s 960us/sample - loss: 70.9484 - mean_absolute_error: 63.8066 - val_loss: 49.9604 - val_mean_absolute_error: 42.9358
# Epoch 10/100
# 327/327 [==============================] - 0s 844us/sample - loss: 68.9253 - mean_absolute_error: 62.1160 - val_loss: 55.6902 - val_mean_absolute_error: 49.0436
# Epoch 11/100
# 327/327 [==============================] - 0s 819us/sample - loss: 68.0122 - mean_absolute_error: 61.4612 - val_loss: 45.8731 - val_mean_absolute_error: 39.3856
# Epoch 12/100
# 327/327 [==============================] - 0s 865us/sample - loss: 64.7623 - mean_absolute_error: 58.3636 - val_loss: 45.1930 - val_mean_absolute_error: 38.8419
# Epoch 13/100
# 327/327 [==============================] - 0s 865us/sample - loss: 66.4421 - mean_absolute_error: 60.2539 - val_loss: 61.8690 - val_mean_absolute_error: 55.7768
# Epoch 14/100
# 327/327 [==============================] - 0s 880us/sample - loss: 63.5819 - mean_absolute_error: 57.5918 - val_loss: 46.9219 - val_mean_absolute_error: 41.0098
# Epoch 15/100
# 327/327 [==============================] - 0s 899us/sample - loss: 63.7055 - mean_absolute_error: 57.8555 - val_loss: 43.0525 - val_mean_absolute_error: 37.1556
# Epoch 16/100
# 327/327 [==============================] - 0s 889us/sample - loss: 65.1103 - mean_absolute_error: 59.2201 - val_loss: 51.0939 - val_mean_absolute_error: 45.2598
# Epoch 17/100
# 327/327 [==============================] - 0s 877us/sample - loss: 65.9226 - mean_absolute_error: 60.1833 - val_loss: 52.6352 - val_mean_absolute_error: 46.9965
# Epoch 18/100
# 327/327 [==============================] - 0s 915us/sample - loss: 63.3021 - mean_absolute_error: 57.7044 - val_loss: 63.2066 - val_mean_absolute_error: 57.6881
# Epoch 19/100
# 327/327 [==============================] - 0s 902us/sample - loss: 64.8663 - mean_absolute_error: 59.3802 - val_loss: 60.4587 - val_mean_absolute_error: 55.0882
# Epoch 20/100
# 327/327 [==============================] - 0s 1ms/sample - loss: 63.8179 - mean_absolute_error: 58.5218 - val_loss: 48.8114 - val_mean_absolute_error: 43.5842
# Epoch 21/100
# 327/327 [==============================] - 0s 914us/sample - loss: 64.6764 - mean_absolute_error: 59.5215 - val_loss: 44.2616 - val_mean_absolute_error: 39.0785
# Epoch 22/100
# 327/327 [==============================] - 0s 889us/sample - loss: 62.0777 - mean_absolute_error: 56.9589 - val_loss: 46.7900 - val_mean_absolute_error: 41.7274
# Epoch 23/100
# 327/327 [==============================] - 0s 883us/sample - loss: 62.4680 - mean_absolute_error: 57.5036 - val_loss: 47.6520 - val_mean_absolute_error: 42.7917
# Epoch 24/100
# 327/327 [==============================] - 0s 889us/sample - loss: 63.6696 - mean_absolute_error: 58.8561 - val_loss: 66.1453 - val_mean_absolute_error: 61.4518
# Epoch 25/100
# 327/327 [==============================] - 0s 909us/sample - loss: 62.2409 - mean_absolute_error: 57.5191 - val_loss: 53.1473 - val_mean_absolute_error: 48.4745
# Epoch 26/100
# 327/327 [==============================] - 0s 874us/sample - loss: 61.8978 - mean_absolute_error: 57.2441 - val_loss: 57.8121 - val_mean_absolute_error: 53.2811
# Epoch 27/100
# 327/327 [==============================] - 0s 828us/sample - loss: 63.4216 - mean_absolute_error: 58.8000 - val_loss: 44.0420 - val_mean_absolute_error: 39.4385
# Epoch 28/100
# 327/327 [==============================] - 0s 868us/sample - loss: 59.8944 - mean_absolute_error: 55.3681 - val_loss: 44.7372 - val_mean_absolute_error: 40.1473
# Epoch 29/100
# 327/327 [==============================] - 0s 871us/sample - loss: 63.5920 - mean_absolute_error: 59.1974 - val_loss: 44.7383 - val_mean_absolute_error: 40.2759
# Epoch 30/100
# 327/327 [==============================] - 0s 896us/sample - loss: 61.1265 - mean_absolute_error: 56.7161 - val_loss: 42.6710 - val_mean_absolute_error: 38.2219
# Epoch 31/100
# 327/327 [==============================] - 0s 880us/sample - loss: 62.8508 - mean_absolute_error: 58.4600 - val_loss: 53.2371 - val_mean_absolute_error: 48.9111
# Epoch 32/100
# 327/327 [==============================] - 0s 860us/sample - loss: 59.4459 - mean_absolute_error: 55.1220 - val_loss: 51.8935 - val_mean_absolute_error: 47.6378
# Epoch 33/100
# 327/327 [==============================] - 0s 914us/sample - loss: 59.6649 - mean_absolute_error: 55.3655 - val_loss: 54.0008 - val_mean_absolute_error: 49.7388
# Epoch 34/100
# 327/327 [==============================] - 0s 911us/sample - loss: 63.0838 - mean_absolute_error: 58.9785 - val_loss: 44.1019 - val_mean_absolute_error: 40.1919
# Epoch 35/100
# 327/327 [==============================] - 0s 917us/sample - loss: 60.1868 - mean_absolute_error: 56.2942 - val_loss: 42.3405 - val_mean_absolute_error: 38.4285
# Epoch 36/100
# 327/327 [==============================] - 0s 914us/sample - loss: 58.8908 - mean_absolute_error: 55.0154 - val_loss: 51.6419 - val_mean_absolute_error: 47.8123
# Epoch 37/100
# 327/327 [==============================] - 0s 892us/sample - loss: 58.7434 - mean_absolute_error: 54.8960 - val_loss: 43.3996 - val_mean_absolute_error: 39.5252
# Epoch 38/100
# 327/327 [==============================] - 0s 899us/sample - loss: 61.2502 - mean_absolute_error: 57.4307 - val_loss: 43.7334 - val_mean_absolute_error: 39.8992
# Epoch 39/100
# 327/327 [==============================] - 0s 959us/sample - loss: 60.3196 - mean_absolute_error: 56.5362 - val_loss: 42.8366 - val_mean_absolute_error: 39.0567
# Epoch 40/100
# 327/327 [==============================] - 0s 877us/sample - loss: 60.1040 - mean_absolute_error: 56.3601 - val_loss: 47.0563 - val_mean_absolute_error: 43.3296
# Epoch 41/100
# 327/327 [==============================] - 0s 902us/sample - loss: 58.0581 - mean_absolute_error: 54.3596 - val_loss: 44.7804 - val_mean_absolute_error: 41.1191
# Epoch 42/100
# 327/327 [==============================] - 0s 886us/sample - loss: 58.9279 - mean_absolute_error: 55.2870 - val_loss: 43.6589 - val_mean_absolute_error: 40.0238
# Epoch 43/100
# 327/327 [==============================] - 0s 862us/sample - loss: 58.2355 - mean_absolute_error: 54.6309 - val_loss: 46.3677 - val_mean_absolute_error: 42.7862
# Epoch 44/100
# 327/327 [==============================] - 0s 862us/sample - loss: 59.2379 - mean_absolute_error: 55.6578 - val_loss: 46.3504 - val_mean_absolute_error: 42.7934
# Epoch 45/100
# 327/327 [==============================] - 0s 837us/sample - loss: 60.1084 - mean_absolute_error: 56.5688 - val_loss: 42.3285 - val_mean_absolute_error: 38.7849
# Epoch 46/100
# 327/327 [==============================] - 0s 913us/sample - loss: 58.4867 - mean_absolute_error: 55.0074 - val_loss: 49.8126 - val_mean_absolute_error: 46.3860
# Epoch 47/100
# 327/327 [==============================] - 0s 831us/sample - loss: 58.3101 - mean_absolute_error: 54.8575 - val_loss: 44.3850 - val_mean_absolute_error: 40.9262
# Epoch 48/100
# 327/327 [==============================] - 0s 865us/sample - loss: 61.5419 - mean_absolute_error: 58.1049 - val_loss: 46.7222 - val_mean_absolute_error: 43.3369
# Epoch 49/100
# 327/327 [==============================] - 0s 865us/sample - loss: 58.5398 - mean_absolute_error: 55.1677 - val_loss: 44.5016 - val_mean_absolute_error: 41.0806
# Epoch 50/100
# 327/327 [==============================] - 0s 868us/sample - loss: 59.6597 - mean_absolute_error: 56.2968 - val_loss: 42.8917 - val_mean_absolute_error: 39.5278
# Epoch 51/100
# 327/327 [==============================] - 0s 844us/sample - loss: 57.9933 - mean_absolute_error: 54.6756 - val_loss: 48.0897 - val_mean_absolute_error: 44.8327
# Epoch 52/100
# 327/327 [==============================] - 0s 813us/sample - loss: 60.3733 - mean_absolute_error: 57.1145 - val_loss: 49.0209 - val_mean_absolute_error: 45.8013
# Epoch 53/100
# 327/327 [==============================] - 0s 879us/sample - loss: 58.1666 - mean_absolute_error: 54.9424 - val_loss: 45.1860 - val_mean_absolute_error: 41.9735
# Epoch 54/100
# 327/327 [==============================] - 0s 828us/sample - loss: 57.4544 - mean_absolute_error: 54.2577 - val_loss: 52.5515 - val_mean_absolute_error: 49.4133
# Epoch 55/100
# 327/327 [==============================] - 0s 899us/sample - loss: 56.7266 - mean_absolute_error: 53.5575 - val_loss: 44.3715 - val_mean_absolute_error: 41.2301
# Epoch 56/100
# 327/327 [==============================] - 0s 840us/sample - loss: 57.1049 - mean_absolute_error: 53.9798 - val_loss: 48.2610 - val_mean_absolute_error: 45.2014
# Epoch 57/100
# 327/327 [==============================] - 0s 862us/sample - loss: 58.1989 - mean_absolute_error: 55.1287 - val_loss: 41.0490 - val_mean_absolute_error: 37.9613
# Epoch 58/100
# 327/327 [==============================] - 0s 810us/sample - loss: 57.7714 - mean_absolute_error: 54.7143 - val_loss: 51.4661 - val_mean_absolute_error: 48.4488
# Epoch 59/100
# 327/327 [==============================] - 0s 825us/sample - loss: 58.8292 - mean_absolute_error: 55.7964 - val_loss: 42.0481 - val_mean_absolute_error: 39.0207
# Epoch 60/100
# 327/327 [==============================] - 0s 845us/sample - loss: 57.4530 - mean_absolute_error: 54.4581 - val_loss: 42.5962 - val_mean_absolute_error: 39.5780
# Epoch 61/100
# 327/327 [==============================] - 0s 874us/sample - loss: 59.4976 - mean_absolute_error: 56.5137 - val_loss: 42.0014 - val_mean_absolute_error: 39.0231
# Epoch 62/100
# 327/327 [==============================] - 0s 865us/sample - loss: 59.6134 - mean_absolute_error: 56.6768 - val_loss: 43.2430 - val_mean_absolute_error: 40.3188
# Epoch 63/100
# 327/327 [==============================] - 0s 813us/sample - loss: 57.5957 - mean_absolute_error: 54.6896 - val_loss: 44.2162 - val_mean_absolute_error: 41.3284
# Epoch 64/100
# 327/327 [==============================] - 0s 825us/sample - loss: 57.9318 - mean_absolute_error: 55.0539 - val_loss: 44.6676 - val_mean_absolute_error: 41.7979
# Epoch 65/100
# 327/327 [==============================] - 0s 801us/sample - loss: 56.2852 - mean_absolute_error: 53.4405 - val_loss: 43.8686 - val_mean_absolute_error: 41.0373
# Epoch 66/100
# 327/327 [==============================] - 0s 840us/sample - loss: 57.7028 - mean_absolute_error: 54.8888 - val_loss: 41.6716 - val_mean_absolute_error: 38.8487
# Epoch 67/100
# 327/327 [==============================] - 0s 860us/sample - loss: 56.7833 - mean_absolute_error: 54.0056 - val_loss: 40.8759 - val_mean_absolute_error: 38.0676
# Epoch 68/100
# 327/327 [==============================] - 0s 883us/sample - loss: 57.7398 - mean_absolute_error: 54.9922 - val_loss: 41.4171 - val_mean_absolute_error: 38.6505
# Epoch 69/100
# 327/327 [==============================] - 0s 871us/sample - loss: 56.6483 - mean_absolute_error: 53.9235 - val_loss: 47.5372 - val_mean_absolute_error: 44.8601
# Epoch 70/100
# 327/327 [==============================] - 0s 880us/sample - loss: 56.5516 - mean_absolute_error: 53.8629 - val_loss: 44.9998 - val_mean_absolute_error: 42.3437
# Epoch 71/100
# 327/327 [==============================] - 0s 947us/sample - loss: 57.8712 - mean_absolute_error: 55.2145 - val_loss: 44.7633 - val_mean_absolute_error: 42.0373
# Epoch 72/100
# 327/327 [==============================] - 0s 844us/sample - loss: 59.3794 - mean_absolute_error: 56.7312 - val_loss: 39.6098 - val_mean_absolute_error: 36.9619
# Epoch 73/100
# 327/327 [==============================] - 0s 871us/sample - loss: 55.8655 - mean_absolute_error: 53.2934 - val_loss: 46.6029 - val_mean_absolute_error: 43.9347
# Epoch 74/100
# 327/327 [==============================] - 0s 867us/sample - loss: 59.3153 - mean_absolute_error: 56.7433 - val_loss: 41.7713 - val_mean_absolute_error: 39.1465
# Epoch 75/100
# 327/327 [==============================] - 0s 865us/sample - loss: 56.4758 - mean_absolute_error: 53.9208 - val_loss: 41.3802 - val_mean_absolute_error: 38.8045
# Epoch 76/100
# 327/327 [==============================] - 0s 868us/sample - loss: 55.4632 - mean_absolute_error: 52.9386 - val_loss: 39.2336 - val_mean_absolute_error: 36.6562
# Epoch 77/100
# 327/327 [==============================] - 0s 844us/sample - loss: 57.2129 - mean_absolute_error: 54.6876 - val_loss: 46.8588 - val_mean_absolute_error: 44.3800
# Epoch 78/100
# 327/327 [==============================] - 0s 865us/sample - loss: 56.4534 - mean_absolute_error: 53.9438 - val_loss: 40.0594 - val_mean_absolute_error: 37.4915
# Epoch 79/100
# 327/327 [==============================] - 0s 865us/sample - loss: 56.5933 - mean_absolute_error: 54.0812 - val_loss: 50.0021 - val_mean_absolute_error: 47.5346
# Epoch 80/100
# 327/327 [==============================] - 0s 853us/sample - loss: 56.6693 - mean_absolute_error: 54.1818 - val_loss: 46.5403 - val_mean_absolute_error: 44.0793
# Epoch 81/100
# 327/327 [==============================] - 0s 883us/sample - loss: 55.7990 - mean_absolute_error: 53.3205 - val_loss: 46.0752 - val_mean_absolute_error: 43.6333
# Epoch 82/100
# 327/327 [==============================] - 0s 859us/sample - loss: 56.6455 - mean_absolute_error: 54.1821 - val_loss: 43.9284 - val_mean_absolute_error: 41.4638
# Epoch 83/100
# 327/327 [==============================] - 0s 853us/sample - loss: 56.6595 - mean_absolute_error: 54.2187 - val_loss: 45.2460 - val_mean_absolute_error: 42.8380
# Epoch 84/100
# 327/327 [==============================] - 0s 813us/sample - loss: 55.9799 - mean_absolute_error: 53.5586 - val_loss: 40.8416 - val_mean_absolute_error: 38.3825
# Epoch 85/100
# 327/327 [==============================] - 0s 892us/sample - loss: 57.3421 - mean_absolute_error: 54.9231 - val_loss: 43.4399 - val_mean_absolute_error: 41.0332
# Epoch 86/100
# 327/327 [==============================] - 0s 837us/sample - loss: 56.8958 - mean_absolute_error: 54.5001 - val_loss: 45.0947 - val_mean_absolute_error: 42.7120
# Epoch 87/100
# 327/327 [==============================] - 0s 844us/sample - loss: 57.7781 - mean_absolute_error: 55.3707 - val_loss: 40.6456 - val_mean_absolute_error: 38.2108
# Epoch 88/100
# 327/327 [==============================] - 0s 834us/sample - loss: 59.7308 - mean_absolute_error: 57.3503 - val_loss: 43.4666 - val_mean_absolute_error: 41.0924
# Epoch 89/100
# 327/327 [==============================] - 0s 859us/sample - loss: 57.4572 - mean_absolute_error: 55.1159 - val_loss: 48.1582 - val_mean_absolute_error: 45.8712
# Epoch 90/100
# 327/327 [==============================] - 0s 822us/sample - loss: 56.9085 - mean_absolute_error: 54.5871 - val_loss: 43.5932 - val_mean_absolute_error: 41.2917
# Epoch 91/100
# 327/327 [==============================] - 0s 853us/sample - loss: 57.7652 - mean_absolute_error: 55.4616 - val_loss: 47.6266 - val_mean_absolute_error: 45.3692
# Epoch 92/100
# 327/327 [==============================] - 0s 856us/sample - loss: 55.5146 - mean_absolute_error: 53.2225 - val_loss: 48.1859 - val_mean_absolute_error: 45.9624
# Epoch 93/100
# 327/327 [==============================] - 0s 825us/sample - loss: 55.4697 - mean_absolute_error: 53.2183 - val_loss: 43.3344 - val_mean_absolute_error: 41.0805
# Epoch 94/100
# 327/327 [==============================] - 0s 828us/sample - loss: 56.4195 - mean_absolute_error: 54.1678 - val_loss: 39.9928 - val_mean_absolute_error: 37.7233
# Epoch 95/100
# 327/327 [==============================] - 0s 839us/sample - loss: 56.5267 - mean_absolute_error: 54.3075 - val_loss: 41.3875 - val_mean_absolute_error: 39.1499
# Epoch 96/100
# 327/327 [==============================] - 0s 880us/sample - loss: 56.5998 - mean_absolute_error: 54.3814 - val_loss: 54.0402 - val_mean_absolute_error: 51.8981
# Epoch 97/100
# 327/327 [==============================] - 0s 828us/sample - loss: 59.5919 - mean_absolute_error: 57.3916 - val_loss: 42.5870 - val_mean_absolute_error: 40.4137
# Epoch 98/100
# 327/327 [==============================] - 0s 837us/sample - loss: 56.4596 - mean_absolute_error: 54.2985 - val_loss: 49.5017 - val_mean_absolute_error: 47.3938
# Epoch 99/100
# 327/327 [==============================] - 0s 853us/sample - loss: 56.7046 - mean_absolute_error: 54.5470 - val_loss: 40.3928 - val_mean_absolute_error: 38.1979
# Epoch 100/100
# 327/327 [==============================] - 0s 1ms/sample - loss: 55.7442 - mean_absolute_error: 53.5910 - val_loss: 44.4349 - val_mean_absolute_error: 42.3225
# Final score (RMSE): 71.86109905794927
